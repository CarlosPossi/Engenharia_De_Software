# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosPossi/Engenharia_De_Software/blob/main/Exercicios_da_aula_9_%7C_Eng_Software.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **✏️ Exercício Prático — Hands-on!**
# ###🎯 ***App: "Minha Lista de Tarefas" (To-Do List)***
# **Contexto:** Você vai modelar e prototipar um mini-app de lista de tarefas usando Arquitetura em Camadas + MVC.

# %% [markdown]
# ### ***Parte 1 — Diagrama no Miro***
# **O que fazer:**
# <br>
# 1. Abra o Miro e crie um novo board
# 2. Desenhe as **3 camadas** do sistema (Apresentação, Negócio, Dados)
# 3. Dentro da camada de Apresentação, aplique o MVC:
# * Model: lista de tarefas (título, status: feito/pendente)
# * View: tela principal + tela de adicionar tarefa
# * Controller: ações de adicionar, marcar como feita, excluir
# 4. Use setas para mostrar o fluxo de uma ação (ex: usuário clica em "Adicionar Tarefa")
# 5. Adicione uma legenda de cores

# %% [markdown]
# #### **Legenda de Cores:**
#
# 🟦 Azul → Apresentação / View
# <br>
# 🟨 Amarelo → Negócio / Controller
# <br>
# 🟥 Vermelho → Dados / Model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Comentário sobre o que o diagrama representa e as decisões de modelagem:**
# <br>
# O diagrama representa um aplicativo de lista de tarefas usando arquitetura em camadas e o padrão MVC. A View cuida das telas e interação com o usuário, o Controller processa as ações do sistema e o Model armazena e manipula os dados das tarefas. Essa separação foi utilizada para deixar o sistema mais organizado, fácil de manter e escalável.

# %% [markdown]
# ### ***Parte 2 — Protótipo no Figma***
# **O que fazer:**
# <br>
# 1. No Figma, crie um projeto chamado ToDoApp - SeuNome
# 2. Crie **2 telas** (Frames mobile 390x844):
# * **Tela 1:** Lista de tarefas (com pelo menos 3 itens, botão de adicionar)
# * **Tela 2:** Modal ou tela de adicionar nova tarefa (campo de texto + botão salvar)
# 3. Conecte as telas com **prototype links** (botão "+" leva à Tela 2, botão salvar volta à Tela 1)
# 4. Nomeie os layers seguindo o MVC: View_ListaTarefas, View_AdicionarTarefa

# %% [markdown]
# ![Captura de tela 2026-04-28 174405.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2026-04-28 174415.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2026-04-28 174426.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2026-04-28 174432.png](data:image/png;base64,...)

# %% [markdown]
# 🔗 **Link para o Figma:** https://www.figma.com/design/r0B0sIXTfpMpariKrh6YDk/ToDoApp---Carlos?node-id=0-1&t=Z5k5x6TGcPEOGshD-1

# %% [markdown]
# **Comentário sobre o protótipo do figma:**
# <br>
# O protótipo desenvolvido no Figma representa a interface do aplicativo de lista de tarefas de forma organizada e intuitiva. As telas foram estruturadas para facilitar a navegação do usuário, permitindo adicionar, visualizar e gerenciar tarefas com praticidade. O design segue a separação proposta pela arquitetura MVC, destacando a interação entre apresentação, lógica e dados, além de proporcionar uma experiência visual simples e funcional.
